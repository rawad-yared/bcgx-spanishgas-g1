# %%
import pandas as pd                                                                                                                                                                                                   
df = pd.read_csv("/Users/rawadyared/Desktop/FIE/Data and dictionary/consumption_hourly_2024.csv")                                                                                                                                                                       
df.to_parquet("/Users/rawadyared/bcgx-spanishgas-g1/data/raw/consumption_hourly_2024.parquet", index=False)
